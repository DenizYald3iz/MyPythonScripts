# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders

# %%
smtp_port = 587
smtp_server = "smtp.gmail.com"
email_from = "yourmailaddress@gmail.com"
deleted_list = []
email_to_list = [
                 "meltem.catak@picussecurity.com",
                 "sbarbaros@argegrupdanismanlik.com.tr",
                 "salih.caredar@bisoft.com.tr",
                 "sahapataman@gmail.com",
                 "info@allesgo.com;muhasebe@allesgo.com",
                 "ozgun@iog.com.tr",
                 "lutfi@ozbilen.web.tr",
                 "info@konrul.com",
                 "yagizhanguler@kutu.ai",
                 "eren.uslu19@gmail.com",
                 "mevlutkarapinar@vegayazilim.com.tr",
                 "sb.kuran@gmail.com",
                 "omeralp@gmail.com",
                 "hatice.kaya@tepav.org.tr",
                 "info@teleskop.app",
                 "umut.erdaloglu@teknoritma.com.tr",
                 "info@toalx.com.tr",
                 "bilgi@tetranova.com.tr",
                 "osman@simulagames.com",
                 "info@stb.plus",
                 "info@spexco.com",
                 "Ar-GeVeIsOrtakliklariYonetimi@softtech.com.tr",
                 "sisoft@sisoft.com.tr",
                 "info@sisasoft.com.tr",
                 "info@signumtte.com",
                 "hello@epinkasa.com",
                 "info@spac.com.tr",
                 "mskayali@yandex.com",
                 "ersoycivelek@gmail.com",
                 "info@feedbackprime.com",
                 "karakasaliefe321@gmail.com",
                 "medet.bagci@xor.com.tr",
                 "h@rxt.com.tr",
                 "careers@picussecurity.com",
                 "info@pidata.com.tr",
                 "info@proven.com.tr",
                 "gonca@quinengine.com",
                 "info@phi0.com",
                 "nilhan.yilmaz@pitcher.com",
                 "onr037@gmail.com",
                 "info@proven.com.tr",
                 "info@on7yazilim.com",
                 "kayit@eczafatura.com",
                 "udogan@cyangate.com",
                 "orkunozek15@gmail.com",
                 "barbaros.ucar@numesys.com.tr",
                 "ramazan@nuke.gs",
                 "info@nxsoft.tech",
                 "fatih.karaman@nishbs.com",
                 "info@mkv.com.tr",
                 "info@navapp.com.tr",
                 "contact@nexoftmobile.com",
                 "elifkocak@nexumsoft.com",
                 "bilgi@matforis.com",
                 "info@mecdis.com",
                 "info@meikosoft.com",
                 "yazilim@mikrokom.com",
                 "info@loncatech.com",
                 "arman@loopgames.net",
                 "info@lupe.com.tr",
                 "ozge.vural@mbis.com.tr",
                 "Alper.Sayar@logo.com.tr",
                 "info@lotec.com.tr",
                 "cihan@laborbilisim.com",
                 "adem.cicek@hotmail.com",
                 "info@kapitta.com",
                 "utku.atlas@adverti.com.tr",
                 "ahmety38@gmail.com",
                 "info@hoytek.com.tr",
                 "info@inappto.com.tr",
                 "info@infoline-tr.com",
                 "can.meral@hypermonkgames.com",
                 "yak@harptek.com",
                 "melisorakci@gmail.com",
                 "proje@hightechs.com.tr",
                 "ahmet.senturk@heapgames.com",
                 "ndemir@guris.com.tr",
                 "info@grakgrakcargo.com",
                 "info@gammate.studio",
                 "info@flatgames.com",
                 "measlantas@fonetyazilim.com",
                 "safiye.durak@forte.com.tr",
                 "hilmigurkan@gmail.com",
                 "bilgi@etgigrup.com",
                 "finance@etiya.com",
                 "info@eywin.com.tr",
                 "info@firestudios.io",
                 "info@estep.com.tr",
                 "info@eldbilisim.com.tr",
                 "ekin@ekonteknoloji.com",
                 "info@ekodenge.com",
                 "muhasebe@e-imzatr.com.tr",
                 "info@arksoft.com.tr",
                 "info@extremepacs.com",
                 "ersungulbas@gmail.com",
                 "info@devbu.com",
                 "ilker@durubilgisayar.com",
                 "proje@dallmeier.com.tr",
                 "info@eb.com.tr;niran.muslu@eb.com.tr",
                 "proje@consultech.com.tr",
                 "craftgamesanonim@gmail.com",
                 "muhasebe@bilgesgt.com",
                 "ali@datascope.ai",
                 "merve06cngz@gmail.com",
                 "s.yildirim@cudatech.com.tr",
                 "bilgi@cypoint.com.tr",
                 "s.evcim@cudatech.com.tr",
                 "info@ceysavunma.com",
                 "info@bilgisim.com.tr",
                 "ender@bilintek.com.tr",
                 "info@bilyazilim.com",
                 "belsis@belsis.com.tr",
                 "berkbozkurt@gmail.com",
                 "askoyuncugil@yahoo.com",
                 "iletisim@bilfo.com.tr",
                 "ekremkabatas1@gmail.com",
                 "atreusmuhasebe@hotmail.com",
                 "info@benpetto.com",
                 "oaytekin@bytecraft.com.tr",
                 "proje@ardholding.com.tr",
                 "proje@ardproje.com.tr",
                 "proje@ardsavunma.com.tr",
                 "arge@arkitek.com.tr",
                 "info@monolib.net",
                 "eren.yasar@amazoisoftware.com",
                 "info@aniventi.com",
                 "proje@ardgayrimenkul.com.tr",
                 "sbarbaros@argegrupdanismanlik.com.tr",
                 "mgundogdu@aivigo.com",
                 "info@aak.com.tr",
                 "proje@ardsaglik.com.tr",
                 "bilgi@alkamanas.com",
                 "info@amazoisoftware.com",
                 "proje@ardenerji.com.tr",
                 "mustafa@ajansiletisim.com.tr",
                 "info@3yteknoloji.com.tr",
                 "info@abisteknoloji.com.tr",
                 "info@accelerate.com.tr",
                 "innovation@acibademtechnology.com",
                 "info@acruxco.com",
                 "info@adasoft.com.tr",
                 "info@btech.com.tr",
                 "info@adesso.com.tr",
                 "advancerenglish@gmail.com",
                 "aeon.gamestudio@gmail.com",
                 "inquiries@aeroms.net",
                 "bilgi@agebilisim.com",
                 "info@agrimetre.com",
                 "info@agrovisio.com.tr",
                 "bilgi@aimtech.com.tr",
                 "ik@akakce.com",
                 "ik@dacdisticaret.com",
                 "info@alpimaging.com",
                 "satis@ampyazilim.com.tr",
                 "info@ankaref.com",
                 "info@anketek.com.tr",
                 "info@anova.com.tr",
                 "hr@argosai.com",
                 "info@arlentus.com",
                 "info@arleon.com.tr",
                 "info@armakom.com",
                 "info@arpanet.com.tr",
                 "ik@asisguard.com.tr",
                 "aspilsan@aspilsan.com",
                 "kariyer@basarsoft.com.tr",
                 "bilgi@bamateknoloji.com",
                 "ayyazilim@ayyazilim.com.tr",
                 "info@ayesas.com",
                 "destek@myenocta.com",
                 "careers@pixerylabs.com",
                 "info@aurvis.com",
                 "hq@berenvr.com",
                 "staj@bias.com.tr",
                 "info@biligoba.com",
                 "info@bilimsu.com.tr",
                 "careers@binalyze.com",
                 "info@biosys.com.tr",
                 "bites@bites.com.tr",
                 "info@biyomod.com.tr",
                 "info@bridgewiz.com",
                 "info@bridgewiz.com",
                 "ik@btech.com.tr",
                 "arge@btsgrp.com",
                 "info@cstech.com.tr",
                 "info@cybertech.com.tr",
                 "ik@data-boss.com.tr",
                 "info@robit.com.tr",
                 "info@bte.com.tr",
                 "info@softtech.com.tr",
                 "info@datayol.com.tr",
                 "hr@data-boss.com.tr",
                 "info@eyesoft.com.tr",
                 "info@earfit.com.tr",
                 "info@earsis.com",
                 "info@emekarge.com",
                 "info@emekarge.com",
                 "info@enovas.com.tr",
                 "ik@esensi.com.tr",
                 "info@famecrypt.com.tr",
                 "info@fiberlast.com.tr",
                 "info@filkon-rf.com",
                 "info@flux-es.com",
                 "info@franticgames.net",
                 "info@frumatic.com",
                 "info@gclabmuhendislik.com",
                 "info@geodestek.com",
                 "info@geosys.com.tr",
                 "physiotechh@gmail.com",
                 "iletisim@halici.com.tr",
                 "haser@haser.com",
                 "haser@haser.com",
                 "info@hidrofil.com.tr",
                 "info@hypsus.com.tr",
                 "info@infodif.com",
                 "bilgi@infosoft.com.tr",
                 "info@innova.com.tr",
                 "info@kocsavunma.com.tr",
                 "info@kodlabs.com",
                 "info@kuasoft.com",
                 "info@kuzguntech.com",
                 "info@larsa4d.com",
                 "info@limatek.com.tr",
                 "consult@meddenovo.com",
                 "Info@milcosys.com",
                 "info@milcosys.com",
                 "milsoft@milsoft.com.tr",
                 "hr@milvusrobotics.com",
                 "bilgi@ordulu.com",
                 "info@panteon.games",
                 "info@robusta.ai",
                 "info@mapcodex.com",
                 "info@sdt.com.tr",
                 "hr@sdt.com.tr",
                 "info@miateknoloji.com",
                 "verisis@verisis.com.tr"
                ]
pswd = ""

# %%
email_to_list= [item for item in email_to_list if item not in deleted_list]

# %%
print(email_to_list)
# Out:
# ['info@bridgewiz.com', 'info@bridgewiz.com', 'ik@btech.com.tr', 'arge@btsgrp.com', 'info@cstech.com.tr', 'info@cybertech.com.tr', 'ik@data-boss.com.tr', 'info@robit.com.tr', 'info@bte.com.tr', 'info@softtech.com.tr', 'info@datayol.com.tr', 'hr@data-boss.com.tr', 'info@eyesoft.com.tr', 'info@earfit.com.tr', 'info@earsis.com', 'info@emekarge.com', 'info@emekarge.com', 'info@enovas.com.tr', 'ik@esensi.com.tr', 'info@famecrypt.com.tr', 'info@fiberlast.com.tr', 'info@filkon-rf.com', 'info@flux-es.com', 'info@franticgames.net', 'info@frumatic.com', 'info@gclabmuhendislik.com', 'info@geodestek.com', 'info@geosys.com.tr', 'physiotechh@gmail.com', 'iletisim@halici.com.tr', 'haser@haser.com', 'haser@haser.com', 'info@hidrofil.com.tr', 'info@hypsus.com.tr', 'info@infodif.com', 'bilgi@infosoft.com.tr', 'info@innova.com.tr', 'info@kocsavunma.com.tr', 'info@kodlabs.com', 'info@kuasoft.com', 'info@kuzguntech.com', 'info@larsa4d.com', 'info@limatek.com.tr', 'consult@meddenovo.com', 'Info@milcosys.co
# ...

# %%
subject = "Staj Başvurusu"

# %%
def send_emails(email_to_list):
    for person in email_to_list:
        html_message = "CONTENT"
        
        # make a MIME object to define parts of the email
        msg = MIMEMultipart()
        msg['From'] = email_from
        msg['To'] = person
        msg['Subject'] = subject

        #attach the body of the message
        msg.attach(MIMEText(html_message, 'html'))
        
        #Attaching the file
        filename = "File NAME"
        attachment = open(filename, 'rb')
        
        # Encode as base 64
        attachment_package = MIMEBase('application', 'octet-stream')
        attachment_package.set_payload((attachment).read())
        encoders.encode_base64(attachment_package)
        attachment_package.add_header('Content-Disposition', "attachment; filename= " + filename)
        msg.attach(attachment_package)

                # Cast as string
        text = msg.as_string()

        # Connect with the server
        print("Connecting to server...")
        TIE_server = smtplib.SMTP(smtp_server, smtp_port)
        TIE_server.starttls()
        TIE_server.login(email_from, pswd)
        print("Succesfully connected to server")
        print()


        # Send emails to "person" as list is iterated
        print(f"Sending email to: {person}...")
        TIE_server.sendmail(email_from, person, text)
        print(f"Email sent to: {person}")
        print()

    # Close the port
    TIE_server.quit()

# %%
# Run the function
send_emails(email_to_list)
# Out:
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: info@bridgewiz.com...
# Email sent to: info@bridgewiz.com
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: info@bridgewiz.com...
# Email sent to: info@bridgewiz.com
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: ik@btech.com.tr...
# Email sent to: ik@btech.com.tr
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: arge@btsgrp.com...
# Email sent to: arge@btsgrp.com
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: info@cstech.com.tr...
# Email sent to: info@cstech.com.tr
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: info@cybertech.com.tr...
# Email sent to: info@cybertech.com.tr
#
# Connecting to server...
# Succesfully connected to server
#
# Sending email to: ik@data-boss.com.tr...
# Email sent to: ik@data-boss.com.tr
#
# ...
